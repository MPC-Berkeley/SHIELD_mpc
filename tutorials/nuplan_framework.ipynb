# %% [markdown]
# ![](https://www.nuplan.org/static/media/nuPlan_final.3fde7586.png)

# %% [markdown]
# ### Contents
#
# 1. [Introduction to nuPlan](#introduction)
# 2. [Training an ML planner](#training)
# 3. [Simulating a planner](#simulation)
# 4. [Visualizing metrics and scenarios](#dashboard)

# %%
from tutorials.utils.tutorial_utils import setup_notebook

setup_notebook()

# %% [markdown]
# # Introduction to nuPlan <a name="introduction"></a>

# %% [markdown]
# Welcome to nuPlan! This notebook will explore the nuPlan simulation framework, training platform as well as the nuBoard metrics/scenarios visualization dashboard.

# %% [markdown]
# ## What is nuPlan
#
# nuPlan is the world’s first closed-loop ML-based planning benchmark for autonomous driving.
#
# It provides a high quality dataset with 1500h of human driving data from 4 cities across the US and Asia with widely varying traffic patterns (Boston, Pittsburgh, Las Vegas and Singapore). In addition, it provides a closed-loop simulation framework with reactive agents, a training platform as well as a large set of both general and scenario-specific planning metrics.
#
# ![](https://www.nuscenes.org/static/media/framework_steps.2d4642df.png)

# %% [markdown]
# ## Training & simulation framework
#
# The nuPlan training and simulation framework aims to:
# * create a simulation pipeline to evaluate a planner on large dataset with various scenarios
# * score planner performance with common and scenario-dependent metrics
# * compare planners based on measured metrics and provide intuitive visualizations
# * train planners with the provided framework to allow quick implementation and iteration
# * support closed-loop simulation and training
#
# <br />
#
# ![](https://www.nuplan.org/static/media/planning_framework.ca3c2969.png)

# %% [markdown]
# ## Scenarios in nuPlan
#
# nuPlan aims to capture challenging yet representative scenarios from real-world encounters. This enables the benchmarking of planning systems both in expert imitation (open-loop) and reactive planning (closed-loop) settings.
#
# These scenarios includes:
# * highly interactive scenes with traffic participants (e.g. tailgating, high-velocity overtakes, double parked cars, jaywalking)
# * various ego behaviors (e.g. vehicle following, yielding, lane merging) and dynamics (e.g. mixed speed profiles, abrupt braking, speed bumps, high jerk maneuvers)
# * scene layouts of varied complexity (e.g. pudos, traffic/stop controlled intersections, unprotected turns) and temporary zones (e.g. construction areas)
#
# The dataset is automatically tagged with scenario labels based on certain primitive attributes.
# These scenario tags can then be used to extract representative metrics for the planner's evaluation.
#
# Example mined scenarios in nuPlan:
#
# | | | |
# | :-: | :-: | :-: |
# | Unprotected cross turn | Dense vehicle interactions | Jaywalker in front |
# | ![](https://www.nuscenes.org/static/media/unprotected-cross.51feef7e.webp) | ![](https://www.nuscenes.org/static/media/dense-interactions.16de47ec.webp) | ![](https://www.nuscenes.org/static/media/jaywalker.03083823.webp) |
# | Lane change | Ego at pickup/dropoff area | Ego following vehicle |
# | ![](https://www.nuscenes.org/static/media/lane-change.54bfca1c.webp) | ![](https://www.nuscenes.org/static/media/pickup-dropoff.4dd1c418.webp) | ![](https://www.nuscenes.org/static/media/following-vehicle.4cacd559.webp) |

# %% [markdown]
# ## Database
#
# Download a database for training/simulation from [here](https://nuplan.org/nuplan#download).
#
# | Database | Size | Duration | Num Logs | Cities | Num Scenarios | Sensor Data | Description |
# | :-- | :-- | :-- | :-- | :-- | :-- | :-- | :-- |
# | nuplan_v1.1_mini (recommended) | 13GB | 7h | 64 | Las Vegas, Boston, Pittsburgh, Singapore | 67 | N/A | The mini split used for prototyping and testing |
# | nuplan_v1.1 | 1.8TB | 1282h | 15910 | Las Vegas, Boston, Pittsburgh, Singapore | 73 | N/A | The full dataset for training and evaluation|

# %% [markdown]
# ## Setup
#
# To be able to access all resources within this notebook, make sure Jupyter is launched at the root of this repo. The path of the notebook should be `/notebook/<repo_root>`.

# %%
# (Optional) Increase notebook width for all embedded cells to display properly
from IPython.core.display import display, HTML
display(HTML("<style>.output_result { max-width:100% !important; }</style>"))
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /tmp/ipykernel_987442/4180358289.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.output_result { max-width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>

# %%
# Useful imports
import os
from pathlib import Path
import tempfile

import hydra

# %% [markdown]
# # Training an ML planner <a name="training"></a>

# %% [markdown]
# ## Imitation learning
# In the following section we will train an ML planning policy with the aim estimate the ego's future trajectory and control the vehicle.
#
# The policy is learned through imitation learning, a supervised learning approach in which - in the context of autonomous driving - the behavior of an expert human driver is used as a target signal to supervise the model.
#
# ## Model features & targets
# A planning policy consumes a set of episodic observations and encodes them through a deep neural network to regress a future trajectory.
#
# The observations can be historic or present ego and agent poses as well as static/dynamic map information across different map layers.<br />
# These signals can be encoded through various representations, such as raster or vector format for the map signal, each with their pros and cons for each model flavor.
#
# Using these input features the model predicts a discretized future trajectory across a fixed time horizon.<br />
# The trajectory consists of a set of discrete future states (position, heading and velocity) sampled at fixed intervals which express the likelihood of the vehicle being at that state in the future.<br />
# For example, a predicted trajectory may consist of 10 future poses sampled at intervals of 0.5s across a 5s horizon.
#
# ## Learning objectives
# The policy is trained to maximize a set of aggregated objectives such as imitation, collision avoidance, traffic rule violation etc.<br />
# Imitation is the core training objective which indicates how close the predicted trajectory is to the expert ground truth and penalizes model predictions that deviate in space and time from the demonstration.

# %% [markdown]
# ## Training parameters

# %% [markdown]
# The following parameter categories define the training protocol which includes the model, metrics, objectives etc.
#
# A working example composition of these parameters can be found in the next section.
#
# ---
#
# ### ML models
#
# Change the training model with `model=X` where `X` is a config yaml defined in the table below.
#
# | Model | Description | Config |
# | --- | --- | --- |
# | Raster model (CNN) | Raster-based model that uses a CNN backbone to encode ego, agent and map information as raster layers<br />Any (pretrained) backbone from the TIMM library can be used (e.g. ResNet50, EfficientNetB3) | `raster_model` |
# | Vector model (LaneGCN) | Vector-based model that uses a series of MLPs to encode ego and agent signals, a lane graph to encode vector-map elements and a fusion network to capture lane & agent intra/inter-interactions through attention layers<br />Implementation of LaneGCN paper ("Learning Lane Graph Representations for Motion Forecasting") | `vector_model` |
# | Simple vector model | Toy vector-based model that consumes ego, agent and lane signals through a series of MLPs | `simple_vector_model` |
#
# <br />
#
# ### Training objectives
#
# Change the training objectives with `objective=[X, ...]` where `X` is a config yaml defined in the table below.
#
# | Objective | Description | Config |
# | --- | --- | --- |
# | Imitation objective | Penalizes the predicted trajectory that deviates from the expert demonstration | `imitation_objective` |
#
# <br />
#
# ### Training metrics
#
# Change the training objectives with `training_metric=[X, ...]` where `X` is a config yaml defined in the table below.
#
# | Metric | Description | Config |
# | --- | --- | --- |
# | Average displacement error | RMSE translation error across full predicted trajectory | `avg_displacement_error` |
# | Average heading error | RMSE heading error across full predicted trajectory | `avg_heading_error` |
# | Final displacement error | L2 error of predicted trajectory's final pose translation | `final_displacement_error` |
# | Final heading error | L2 error of predicted trajectory's final pose heading | `final_heading_error` |

# %% [markdown]
# ## Prepare the training config

# %%
# Location of path with all training configs
CONFIG_PATH = '../nuplan/planning/script/config/training'
CONFIG_NAME = 'default_training'

# Create a temporary directory to store the cache and experiment artifacts
SAVE_DIR = Path(tempfile.gettempdir()) / 'tutorial_nuplan_framework'  # optionally replace with persistent dir
EXPERIMENT = 'training_raster_experiment'
JOB_NAME = 'train_default_raster'
LOG_DIR = SAVE_DIR / EXPERIMENT / JOB_NAME

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'group={str(SAVE_DIR)}',
    f'cache.cache_path={str(SAVE_DIR)}/cache',
    f'experiment_name={EXPERIMENT}',
    f'job_name={JOB_NAME}',
    'py_func=train',
    '+training=training_raster_model',  # raster model that consumes ego, agents and map raster layers and regresses the ego's trajectory
    'scenario_builder=nuplan_mini',  # use nuplan mini database
    'scenario_filter.limit_total_scenarios=500',  # Choose 500 scenarios to train with
    'lightning.trainer.params.accelerator=ddp_spawn',  # ddp is not allowed in interactive environment, using ddp_spawn instead - this can bottleneck the data pipeline, it is recommended to run training outside the notebook
    'lightning.trainer.params.max_epochs=10',
    'data_loader.params.batch_size=8',
    'data_loader.params.num_workers=8',
])

# %% [markdown]
# ## Launch tensorboard for visualizing training artifacts

# %%
# %load_ext tensorboard
# %tensorboard --logdir {str(LOG_DIR)}
# Out:
# Launching TensorBoard...

# %% [markdown]
# ## Launch training (within the notebook)

# %%
from nuplan.planning.script.run_training import main as main_train

# Run the training loop, optionally inspect training artifacts through tensorboard (above cell)
main_train(cfg)
# Out:
# Global seed set to 0
# 2024-06-18 18:52:13,644 INFO {/home/mpc/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:20}  Building experiment folders...
# 2024-06-18 18:52:13,644 INFO {/home/mpc/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:22}  Experimental folder: /tmp/tutorial_nuplan_framework/training_raster_experiment/train_default_raster/2024.06.18.18.52.13
# 2024-06-18 18:52:13,644 INFO {/home/mpc/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2024-06-18 18:52:13,646 INFO {/home/mpc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:78}  Starting ray local!
# 2024-06-18 18:52:15,898	INFO worker.py:1724 -- Started a local Ray instance.
# 2024-06-18 18:52:16,731 INFO {/home/mpc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2024-06-18 18:52:16,731 INFO {/home/mpc/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 16
# Number of GPUs per node: 1
# Number of threads across all nodes: 16
# 2024-06-18 18:52:16,731 INFO {/home/mpc/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2024-06-18 18:52:16,731 INFO {/home/mpc/nuplan-devkit/nuplan/planning/training/experiments/training.py:41}  Building training engine...
# 2024-06-18 18:52:16,731 INFO {/home/mpc/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2024-06-18 18:52:17,174 INFO {/home/mpc/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:186}  Loading pretrained weights from Hugging Face hub (timm/resnet50.a1_in1k)
# Downloading model.safetensors:   0%|          | 0.00/102M [00:00<?, ?B/s]
# 2024-06-18 18:52:24,641 INFO {/home/mpc/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_hub.py:180}  [timm/resnet50.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/hydra/_internal/instantiate/_instantiate2.py:62, in _call_target(target, *args, **kwargs)
#      60             v._set_parent(None)
# ---> 62     return target(*args, **kwargs)
#      63 except Exception as e:
#
# File ~/nuplan-devkit/nuplan/planning/training/modeling/models/raster_model.py:58, in RasterModel.__init__(self, feature_builders, target_builders, model_name, pretrained, num_input_channels, num_features_per_pose, future_trajectory_sampling)
#      57 num_output_features = future_trajectory_sampling.num_poses * num_features_per_pose
# ---> 58 self._model = timm.create_model(model_name, pretrained=pretrained, num_classes=0, in_chans=num_input_channels)
#      59 mlp = torch.nn.Linear(in_features=self._model.num_features, out_features=num_output_features)
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_factory.py:117, in create_model(model_name, pretrained, pretrained_cfg, pretrained_cfg_overlay, checkpoint_path, scriptable, exportable, no_jit, **kwargs)
#     116 with set_layer_config(scriptable=scriptable, exportable=exportable, no_jit=no_jit):
# --> 117     model = create_fn(
#     118         pretrained=pretrained,
#     119         pretrained_cfg=pretrained_cfg,
#     120         pretrained_cfg_overlay=pretrained_cfg_overlay,
#     121         **kwargs,
#     122     )
#     124 if checkpoint_path:
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/resnet.py:1322, in resnet50(pretrained, **kwargs)
#    1321 model_args = dict(block=Bottleneck, layers=[3, 4, 6, 3])
# -> 1322 return _create_resnet('resnet50', pretrained, **dict(model_args, **kwargs))
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/resnet.py:584, in _create_resnet(variant, pretrained, **kwargs)
#     583 def _create_resnet(variant, pretrained: bool = False, **kwargs) -> ResNet:
# --> 584     return build_model_with_cfg(ResNet, variant, pretrained, **kwargs)
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:410, in build_model_with_cfg(model_cls, variant, pretrained, pretrained_cfg, pretrained_cfg_overlay, model_cfg, feature_cfg, pretrained_strict, pretrained_filter_fn, kwargs_filter, **kwargs)
#     409 if pretrained:
# --> 410     load_pretrained(
#     411         model,
#     412         pretrained_cfg=pretrained_cfg,
#     413         num_classes=num_classes_pretrained,
#     414         in_chans=kwargs.get('in_chans', 3),
#     415         filter_fn=pretrained_filter_fn,
#     416         strict=pretrained_strict,
#     417     )
#     419 # Wrap the model in a feature extraction module if enabled
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:190, in load_pretrained(model, pretrained_cfg, num_classes, in_chans, filter_fn, strict)
#     189     else:
# --> 190         state_dict = load_state_dict_from_hf(pretrained_loc)
#     191 else:
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_hub.py:183, in load_state_dict_from_hf(model_id, filename)
#     180     _logger.info(
#     181         f"[{model_id}] Safe alternative available for '{filename}' "
#     182         f"(as '{safe_filename}'). Loading weights using safetensors.")
# --> 183     return safetensors.torch.load_file(cached_safe_file, device="cpu")
#     184 except EntryNotFoundError:
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/safetensors/torch.py:310, in load_file(filename, device)
#     309     for k in f.keys():
# --> 310         result[k] = f.get_tensor(k)
#     311 return result
#
# AttributeError: module 'torch' has no attribute 'frombuffer'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       1 from nuplan.planning.script.run_training import main as main_train
#       3 # Run the training loop, optionally inspect training artifacts through tensorboard (above cell)
# ----> 4 main_train(cfg)
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/hydra/main.py:44, in main.<locals>.main_decorator.<locals>.decorated_main(cfg_passthrough)
#      41 @functools.wraps(task_function)
#      42 def decorated_main(cfg_passthrough: Optional[DictConfig] = None) -> Any:
#      43     if cfg_passthrough is not None:
# ---> 44         return task_function(cfg_passthrough)
#      45     else:
#      46         args = get_args_parser()
#
# File ~/nuplan-devkit/nuplan/planning/script/run_training.py:59, in main(cfg)
#      56 if cfg.py_func == 'train':
#      57     # Build training engine
#      58     with ProfilerContextManager(cfg.output_dir, cfg.enable_profiling, "build_training_engine"):
# ---> 59         engine = build_training_engine(cfg, worker)
#      61     # Run training
#      62     logger.info('Starting training...')
#
# File ~/nuplan-devkit/nuplan/planning/training/experiments/training.py:44, in build_training_engine(cfg, worker)
#      41 logger.info('Building training engine...')
#      43 # Create model
# ---> 44 torch_module_wrapper = build_torch_module_wrapper(cfg.model)
#      46 # Build the datamodule
#      47 datamodule = build_lightning_datamodule(cfg, worker, torch_module_wrapper)
#
# File ~/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:19, in build_torch_module_wrapper(cfg)
#      13 """
#      14 Builds the NN module.
#      15 :param cfg: DictConfig. Configuration that is used to run the experiment.
#      16 :return: Instance of TorchModuleWrapper.
#      17 """
#      18 logger.info('Building TorchModuleWrapper...')
# ---> 19 model = instantiate(cfg)
#      20 validate_type(model, TorchModuleWrapper)
#      21 logger.info('Building TorchModuleWrapper...DONE!')
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/hydra/_internal/instantiate/_instantiate2.py:180, in instantiate(config, *args, **kwargs)
#     177     _recursive_ = config.pop(_Keys.RECURSIVE, True)
#     178     _convert_ = config.pop(_Keys.CONVERT, ConvertMode.NONE)
# --> 180     return instantiate_node(config, *args, recursive=_recursive_, convert=_convert_)
#     181 else:
#     182     raise InstantiationException(
#     183         "Top level config has to be OmegaConf DictConfig, plain dict, or a Structured Config class or instance"
#     184     )
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/hydra/_internal/instantiate/_instantiate2.py:249, in instantiate_node(node, convert, recursive, *args)
#     245                 value = instantiate_node(
#     246                     value, convert=convert, recursive=recursive
#     247                 )
#     248             kwargs[key] = _convert_node(value, convert)
# --> 249     return _call_target(target, *args, **kwargs)
#     250 else:
#     251     # If ALL or PARTIAL non structured, instantiate in dict and resolve interpolations eagerly.
#     252     if convert == ConvertMode.ALL or (
#     253         convert == ConvertMode.PARTIAL and node._metadata.object_type is None
#     254     ):
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/hydra/_internal/instantiate/_instantiate2.py:64, in _call_target(target, *args, **kwargs)
#      62     return target(*args, **kwargs)
#      63 except Exception as e:
# ---> 64     raise type(e)(
#      65         f"Error instantiating '{_convert_target_to_string(target)}' : {e}"
#      66     ).with_traceback(sys.exc_info()[2])
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/hydra/_internal/instantiate/_instantiate2.py:62, in _call_target(target, *args, **kwargs)
#      59         if OmegaConf.is_config(v):
#      60             v._set_parent(None)
# ---> 62     return target(*args, **kwargs)
#      63 except Exception as e:
#      64     raise type(e)(
#      65         f"Error instantiating '{_convert_target_to_string(target)}' : {e}"
#      66     ).with_traceback(sys.exc_info()[2])
#
# File ~/nuplan-devkit/nuplan/planning/training/modeling/models/raster_model.py:58, in RasterModel.__init__(self, feature_builders, target_builders, model_name, pretrained, num_input_channels, num_features_per_pose, future_trajectory_sampling)
#      51 super().__init__(
#      52     feature_builders=feature_builders,
#      53     target_builders=target_builders,
#      54     future_trajectory_sampling=future_trajectory_sampling,
#      55 )
#      57 num_output_features = future_trajectory_sampling.num_poses * num_features_per_pose
# ---> 58 self._model = timm.create_model(model_name, pretrained=pretrained, num_classes=0, in_chans=num_input_channels)
#      59 mlp = torch.nn.Linear(in_features=self._model.num_features, out_features=num_output_features)
#      61 if hasattr(self._model, 'classifier'):
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_factory.py:117, in create_model(model_name, pretrained, pretrained_cfg, pretrained_cfg_overlay, checkpoint_path, scriptable, exportable, no_jit, **kwargs)
#     115 create_fn = model_entrypoint(model_name)
#     116 with set_layer_config(scriptable=scriptable, exportable=exportable, no_jit=no_jit):
# --> 117     model = create_fn(
#     118         pretrained=pretrained,
#     119         pretrained_cfg=pretrained_cfg,
#     120         pretrained_cfg_overlay=pretrained_cfg_overlay,
#     121         **kwargs,
#     122     )
#     124 if checkpoint_path:
#     125     load_checkpoint(model, checkpoint_path)
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/resnet.py:1322, in resnet50(pretrained, **kwargs)
#    1319 """Constructs a ResNet-50 model.
#    1320 """
#    1321 model_args = dict(block=Bottleneck, layers=[3, 4, 6, 3])
# -> 1322 return _create_resnet('resnet50', pretrained, **dict(model_args, **kwargs))
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/resnet.py:584, in _create_resnet(variant, pretrained, **kwargs)
#     583 def _create_resnet(variant, pretrained: bool = False, **kwargs) -> ResNet:
# --> 584     return build_model_with_cfg(ResNet, variant, pretrained, **kwargs)
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:410, in build_model_with_cfg(model_cls, variant, pretrained, pretrained_cfg, pretrained_cfg_overlay, model_cfg, feature_cfg, pretrained_strict, pretrained_filter_fn, kwargs_filter, **kwargs)
#     408 num_classes_pretrained = 0 if features else getattr(model, 'num_classes', kwargs.get('num_classes', 1000))
#     409 if pretrained:
# --> 410     load_pretrained(
#     411         model,
#     412         pretrained_cfg=pretrained_cfg,
#     413         num_classes=num_classes_pretrained,
#     414         in_chans=kwargs.get('in_chans', 3),
#     415         filter_fn=pretrained_filter_fn,
#     416         strict=pretrained_strict,
#     417     )
#     419 # Wrap the model in a feature extraction module if enabled
#     420 if features:
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:190, in load_pretrained(model, pretrained_cfg, num_classes, in_chans, filter_fn, strict)
#     188         state_dict = load_state_dict_from_hf(*pretrained_loc)
#     189     else:
# --> 190         state_dict = load_state_dict_from_hf(pretrained_loc)
#     191 else:
#     192     model_name = pretrained_cfg.get('architecture', 'this model')
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_hub.py:183, in load_state_dict_from_hf(model_id, filename)
#     179     cached_safe_file = hf_hub_download(repo_id=hf_model_id, filename=safe_filename, revision=hf_revision)
#     180     _logger.info(
#     181         f"[{model_id}] Safe alternative available for '{filename}' "
#     182         f"(as '{safe_filename}'). Loading weights using safetensors.")
# --> 183     return safetensors.torch.load_file(cached_safe_file, device="cpu")
#     184 except EntryNotFoundError:
#     185     pass
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/safetensors/torch.py:310, in load_file(filename, device)
#     308 with safe_open(filename, framework="pt", device=device) as f:
#     309     for k in f.keys():
# --> 310         result[k] = f.get_tensor(k)
#     311 return result
#
# AttributeError: Error instantiating 'nuplan.planning.training.modeling.models.raster_model.RasterModel' : module 'torch' has no attribute 'frombuffer'
# (raylet) [2024-06-18 18:52:25,807 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6097690624; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:52:35,812 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6097469440; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:52:45,817 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6097399808; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:52:55,823 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6097338368; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:53:05,828 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6097272832; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:53:15,834 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6097178624; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:53:25,840 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6097035264; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:53:35,848 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6096977920; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:53:45,856 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6096912384; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:53:55,874 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6096846848; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:54:05,880 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6096773120; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:54:15,885 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6096678912; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:54:25,891 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6096412672; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:54:35,897 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6096347136; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:54:45,903 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6096289792; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:54:55,909 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6096216064; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:55:05,915 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6096146432; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:55:15,920 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6096039936; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:55:25,932 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6095880192; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:55:35,945 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6095814656; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:55:45,960 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6095749120; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:55:55,966 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6095552512; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:56:05,972 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6095454208; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:56:15,978 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6095368192; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:56:25,984 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6095122432; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:56:35,990 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6095060992; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:56:45,996 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6094995456; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:56:56,002 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6094925824; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:57:06,009 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6094839808; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:57:16,016 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6094741504; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:57:26,022 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6094598144; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:57:36,044 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6086152192; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:57:46,050 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6086082560; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:57:56,080 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6086012928; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:58:06,088 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6085943296; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:58:16,097 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6085849088; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:58:26,111 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6085713920; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:58:36,117 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6085652480; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:58:46,130 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6085582848; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:58:56,140 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6085525504; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:59:06,152 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6085464064; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:59:16,165 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6085361664; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:59:26,184 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6085226496; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:59:36,190 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6085156864; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:59:46,196 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6085091328; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 18:59:56,202 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6085029888; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:00:06,213 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6084964352; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:00:16,219 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6084878336; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:00:26,232 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6084689920; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:00:36,238 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6084620288; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:00:46,244 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6084558848; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:00:56,251 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6084489216; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:01:06,278 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6084411392; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:01:16,291 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6084317184; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:01:26,298 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6084161536; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:01:36,308 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6084108288; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:01:46,316 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6084038656; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:01:56,327 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6083973120; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:02:06,343 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6083907584; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:02:16,356 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6083821568; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:02:26,361 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6083678208; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:02:36,418 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6083620864; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:02:46,424 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6083551232; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:02:56,430 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6083493888; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:03:06,438 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6083428352; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:03:16,447 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6083325952; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:03:26,455 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6083137536; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:03:36,464 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6083076096; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:03:46,473 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6083002368; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:03:56,499 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6082945024; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:04:06,506 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6082875392; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:04:16,517 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6082785280; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:04:26,523 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6082637824; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:04:36,551 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6082564096; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:04:46,565 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6082498560; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:04:56,571 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6082437120; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:05:06,579 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6082371584; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:05:16,589 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6082248704; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:05:26,609 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6082101248; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:05:36,618 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6082031616; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:05:46,625 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6081974272; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:05:56,641 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6081908736; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:06:06,652 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6081826816; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:06:16,662 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6081671168; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:06:26,672 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6081576960; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:06:36,688 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6081503232; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:06:46,694 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6081441792; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:06:56,706 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6081372160; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:07:06,732 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6072926208; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:07:16,741 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6072750080; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:07:26,755 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6072692736; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:07:36,766 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6072635392; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:07:46,785 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6072565760; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:07:56,793 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6072504320; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:08:06,800 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6072438784; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:08:16,807 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6072213504; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:08:26,819 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6072147968; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:08:36,825 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6072074240; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:08:46,832 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6072008704; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:08:56,845 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6071947264; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:09:06,850 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6071750656; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:09:16,856 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6071574528; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:09:26,862 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6071513088; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:09:36,867 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6071447552; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:09:46,873 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6071382016; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:09:56,879 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6071320576; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:10:06,884 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6071255040; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:10:16,897 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6071046144; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:10:26,916 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6070976512; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:10:36,923 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6070906880; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:10:46,929 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6070710272; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:10:56,935 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6070644736; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:11:06,941 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6070566912; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:11:16,947 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6070374400; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:11:26,953 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6070312960; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:11:36,959 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6070243328; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:11:46,970 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6070181888; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:11:56,984 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6070112256; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:12:06,993 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6070046720; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:12:17,003 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6069874688; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:12:27,019 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6069805056; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:12:37,054 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6069747712; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:12:47,059 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6069682176; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:12:57,065 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6069481472; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:13:07,070 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6069420032; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:13:17,076 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6069190656; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:13:27,082 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6069129216; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:13:37,088 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6069063680; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-18 19:13:47,094 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 6068998144; capacity: 307484811264. Object creation will fail if spilling is required.
# ...
# (raylet) [2024-06-19 03:57:07,557 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559402496; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 03:57:17,568 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559382016; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 03:57:27,574 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559369728; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 03:57:37,580 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559369728; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 03:57:47,585 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559345152; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 03:57:57,595 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559341056; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 03:58:07,601 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559341056; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 03:58:17,612 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559320576; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 03:58:27,618 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559316480; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 03:58:37,623 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559312384; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 03:58:47,631 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559287808; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 03:58:57,639 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559283712; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 03:59:07,645 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559271424; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 03:59:17,651 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559250944; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 03:59:27,657 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559111680; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 03:59:37,663 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559107584; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 03:59:47,669 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559087104; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 03:59:57,674 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559078912; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:00:07,680 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559070720; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:00:17,686 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559050240; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:00:27,697 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559042048; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:00:37,703 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559042048; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:00:47,708 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559021568; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:00:57,714 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559013376; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:01:07,721 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5559013376; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:01:17,727 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558992896; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:01:27,733 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558984704; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:01:37,739 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558972416; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:01:47,745 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558947840; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:01:57,751 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558947840; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:02:07,757 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558947840; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:02:17,766 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558923264; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:02:27,773 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558919168; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:02:37,778 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558910976; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:02:47,786 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558890496; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:02:57,795 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558886400; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:03:07,801 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558878208; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:03:17,815 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558726656; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:03:27,821 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558722560; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:03:37,828 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558714368; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:03:47,835 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558693888; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:03:57,841 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558685696; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:04:07,848 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558681600; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:04:17,855 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558669312; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:04:27,860 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558652928; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:04:37,866 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558644736; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:04:47,872 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558624256; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:04:57,878 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558616064; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:05:07,884 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558611968; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:05:17,890 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558595584; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:05:27,896 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558591488; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:05:37,902 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558587392; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:05:47,909 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558558720; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:05:57,915 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558423552; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:06:07,920 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558300672; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:06:17,927 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558280192; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:06:27,933 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558267904; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:06:37,939 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558267904; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:06:47,946 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558243328; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:06:57,952 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558243328; capacity: 307484811264. Object creation will fail if spilling is required.
# (raylet) [2024-06-19 04:07:07,966 E 987858 987894] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2024-06-18_18-52-13_671548_987442 is over 95% full, available space: 5558235136; capacity: 307484811264. Object creation will fail if spilling is required.

# %% [markdown]
# ## Launch training (command line - alternative)

# %% [markdown]
# A training experiment with the above same parameters can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_training.py \
#     experiment_name=raster_experiment \
#     py_func=train \
#     +training=training_raster_model \
#     scenario_builder=nuplan_mini \
#     scenario_filter.limit_total_scenarios=500 \
#     lightning.trainer.params.max_epochs=10 \
#     data_loader.params.batch_size=8 \
#     data_loader.params.num_workers=8
# ```

# %% [markdown]
# # Simulating a planner <a name="simulation"></a>

# %% [markdown]
# ## Open-loop simulation
# Open-loop simulation aims to evaluate the policy's capabilities to imitate the expert driver's behavior.<br />
# This is essentially done through log replay as the policy's predictions do not affect the state of the simulation.
#
# As the policy is not in full control of the vehicle, this type of simulation can only provide a high-level performance overview.
#
# ## Closed-loop simulation
# Conversely, in closed-loop simulation the policy's actions alter the state of the simulation which tries to closely approximate the real-world system.
#
# The simulation's feedback loop enables a more in-depth evaluation of the policy as compounding errors can cause future observations to significantly diverge from the ground truth.<br />
# This is important in measuring distribution shifts introduced due to lack of variance in training examples through pure imitation learning.
#
# Closed-loop simulation is further divided into two categories:
# * ego closed-loop simulation with agents replayed from log (open-loop, non reactive)
# * ego closed-loop simulation with agents controlled by a rule-based or learned policy (closed-loop, reactive)
#
# ## Measuring success
# Measuring the success of a planning task and comparing various planning policies is a complicated effort that involves defining metrics across different vertical dimensions and scenario categories.<br />
# These metrics include indicators such as vehicle dynamics, traffic rule violations, expert imitation, navigation success etc.<br />
# Overall, they aim to capture the policy's ability to control the autonomous vehicle safely yet efficiently without compromising the passenger's comfort.

# %% [markdown]
# ## Simulation parameters

# %% [markdown]
# ### Planners
#
# Change the planner model with `planner=X` where `X` is a config yaml defined in the table below.
#
# | Planner | Description | Config |
# | --- | --- | --- |
# | Simple Planner | Naive planner that only plans a straight path | `simple_planner` |
# | ML Planner | Learning-based planner trained using the nuPlan training framework (see previous section) | `ml_planner` |

# %% [markdown]
# ## Prepare the simulation config

# %%
# Location of path with all simulation configs
CONFIG_PATH = '../nuplan/planning/script/config/simulation'
CONFIG_NAME = 'default_simulation'

# Select the planner and simulation challenge
PLANNER = 'simple_planner'  # [simple_planner, ml_planner]
CHALLENGE = 'open_loop_boxes'  # [open_loop_boxes, closed_loop_nonreactive_agents, closed_loop_reactive_agents]
DATASET_PARAMS = [
    'scenario_builder=nuplan_mini',  # use nuplan mini database
    'scenario_filter=all_scenarios',  # initially select all scenarios in the database
    'scenario_filter.scenario_types=[near_multiple_vehicles, on_pickup_dropoff, starting_unprotected_cross_turn, high_magnitude_jerk]',  # select scenario types
    'scenario_filter.num_scenarios_per_type=10',  # use 10 scenarios per scenario type
]

# Name of the experiment
EXPERIMENT = 'simulation_simple_experiment'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'experiment_name={EXPERIMENT}',
    f'group={SAVE_DIR}',
    f'planner={PLANNER}',
    f'+simulation={CHALLENGE}',
    *DATASET_PARAMS,
])

# %% [markdown]
# ## Launch simulation (within the notebook)

# %%
from nuplan.planning.script.run_simulation import main as main_simulation

# Run the simulation loop (real-time visualization not yet supported, see next section for visualization)
main_simulation(cfg)

# Simple simulation folder for visualization in nuBoard
simple_simulation_folder = cfg.output_dir
# Out:
# Global seed set to 0
# 2023-04-25 17:30:35,403 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:20}  Building MultiMainCallback...
# 2023-04-25 17:30:35,492 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:35}  Building MultiMainCallback: 4...DONE!
# 2023-04-25 17:30:35,655 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2023-04-25 17:30:35,656 WARNING {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:135}  Ray is running, we will shut it down before starting again!
# 2023-04-25 17:30:37,990 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:78}  Starting ray local!
# 2023-04-25 17:30:40,069	INFO worker.py:1553 -- Started a local Ray instance.
# 2023-04-25 17:30:40,776 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2023-04-25 17:30:40,777 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 32
# Number of GPUs per node: 1
# Number of threads across all nodes: 32
# 2023-04-25 17:30:40,777 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2023-04-25 17:30:40,777 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}  Building experiment folders...
# 2023-04-25 17:30:40,777 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:35}
#
# 	Folder where all results are stored: /tmp/tutorial_nuplan_framework/simulation_simple_experiment/open_loop_boxes/2023.04.25.17.30.35
#
# 2023-04-25 17:30:40,779 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:70}  Building experiment folders...DONE!
# 2023-04-25 17:30:40,780 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2023-04-25 17:30:40,780 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:68}  Building AbstractCallback: 0...DONE!
# 2023-04-25 17:30:40,780 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:47}  Building simulations...
# 2023-04-25 17:30:40,780 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:53}  Extracting scenarios...
# 2023-04-25 17:30:40,781 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/common/utils/distributed_scenario_filter.py:83}  Building Scenarios in mode DistributedMode.SINGLE_NODE
# 2023-04-25 17:30:40,781 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2023-04-25 17:30:40,798 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2023-04-25 17:30:40,799 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2023-04-25 17:30:40,800 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# Ray objects: 100%|████████████████████████████████████████████████████████████████████| 32/32 [00:02<00:00, 15.48it/s]
# 2023-04-25 17:30:42,909 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:74}  Building metric engines...
# 2023-04-25 17:30:42,942 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:76}  Building metric engines...DONE
# 2023-04-25 17:30:42,942 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:80}  Building simulations from 31 scenarios...
# 2023-04-25 17:30:48,221 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:133}  Building simulations...DONE!
# 2023-04-25 17:30:48,221 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/run_simulation.py:78}  Running simulation...
# 2023-04-25 17:30:48,221 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/utils.py:138}  Executing runners...
# 2023-04-25 17:30:48,221 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:82}  Starting 31 simulations using RayDistributed!
# Ray objects: 100%|████████████████████████████████████████████████████████████████████| 31/31 [00:13<00:00,  2.22it/s]
# 2023-04-25 17:31:02,230 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:127}  Number of successful simulations: 31
# 2023-04-25 17:31:02,231 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:128}  Number of failed simulations: 0
# 2023-04-25 17:31:02,231 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/utils.py:147}  Finished executing runners!
# 2023-04-25 17:31:02,244 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/utils.py:74}  Saved runner reports to /tmp/tutorial_nuplan_framework/simulation_simple_experiment/open_loop_boxes/2023.04.25.17.30.35/runner_report.parquet
# 2023-04-25 17:31:02,244 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/simulation/main_callback/time_callback.py:27}  Simulation duration: 00:00:26 [HH:MM:SS]
# 2023-04-25 17:31:02,551 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_file_callback.py:79}  Metric files integration: 00:00:00 [HH:MM:SS]
# 2023-04-25 17:31:02,580 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:58}  Running metric aggregator: open_loop_boxes_weighted_average
# 2023-04-25 17:31:02,598 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:69}  Metric aggregator: 00:00:00 [HH:MM:SS]
# Rendering histograms: 100%|█████████████████████████████████████████████████████████████| 6/6 [00:01<00:00,  4.68it/s]
# 2023-04-25 17:31:04,684 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_summary_callback.py:344}  Metric summary: 00:00:02 [HH:MM:SS]
# 2023-04-25 17:31:04,684 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/run_simulation.py:80}  Finished running simulation!

# %% [markdown]
# ## Launch simulation (command line - alternative)

# %% [markdown]
# A simulation experiment can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_simulation.py \
#     +simulation=open_loop_boxes \
#     planner=simple_planner \
#     scenario_builder=nuplan_mini \
#     scenario_filter=all_scenarios \
#     scenario_filter.scenario_types="[near_multiple_vehicles, on_pickup_dropoff, starting_unprotected_cross_turn, high_magnitude_jerk]" \
#     scenario_filter.num_scenarios_per_type=10 \
# ```

# %% [markdown]
# ## Simulate a trained ML planner for comparison
#
# Using the same simulation settings as before, we can simulate a pretrained ML planner and compare the two.
#
# In this example you can take the model you trained earlier.

# %%
# Location of path with all simulation configs
CONFIG_PATH = '../nuplan/planning/script/config/simulation'
CONFIG_NAME = 'default_simulation'

# Get the checkpoint of the trained model
last_experiment = sorted(os.listdir(LOG_DIR))[-1]
train_experiment_dir = sorted(LOG_DIR.iterdir())[-1]
checkpoint = sorted((train_experiment_dir / 'checkpoints').iterdir())[-1]

MODEL_PATH = str(checkpoint).replace("=", "\=")

# Name of the experiment
EXPERIMENT = 'simulation_raster_experiment'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'experiment_name={EXPERIMENT}',
    f'group={SAVE_DIR}',
    'planner=ml_planner',
    'model=raster_model',
    'planner.ml_planner.model_config=${model}',  # hydra notation to select model config
    f'planner.ml_planner.checkpoint_path={MODEL_PATH}',  # this path can be replaced by the checkpoint of the model trained in the previous section
    f'+simulation={CHALLENGE}',
    *DATASET_PARAMS,
])

# Run the simulation loop
main_simulation(cfg)

# ML_planner simulation folder for visualization in nuBoard (next section)
ml_planner_simulation_folder = cfg.output_dir
# Out:
# Global seed set to 0
# 2023-04-25 17:31:09,399 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:20}  Building MultiMainCallback...
# 2023-04-25 17:31:09,416 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:35}  Building MultiMainCallback: 4...DONE!
# 2023-04-25 17:31:09,583 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2023-04-25 17:31:09,583 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2023-04-25 17:31:09,584 WARNING {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:135}  Ray is running, we will shut it down before starting again!
# 2023-04-25 17:31:09,584 WARNING {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:135}  Ray is running, we will shut it down before starting again!
# 2023-04-25 17:31:11,251 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:78}  Starting ray local!
# 2023-04-25 17:31:11,251 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:78}  Starting ray local!
# 2023-04-25 17:31:13,248	INFO worker.py:1553 -- Started a local Ray instance.
# 2023-04-25 17:31:13,995 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2023-04-25 17:31:13,995 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2023-04-25 17:31:13,996 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 32
# Number of GPUs per node: 1
# Number of threads across all nodes: 32
# 2023-04-25 17:31:13,996 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 32
# Number of GPUs per node: 1
# Number of threads across all nodes: 32
# 2023-04-25 17:31:13,996 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2023-04-25 17:31:13,996 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2023-04-25 17:31:13,996 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}  Building experiment folders...
# 2023-04-25 17:31:13,996 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}  Building experiment folders...
# 2023-04-25 17:31:13,997 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:35}
#
# 	Folder where all results are stored: /tmp/tutorial_nuplan_framework/simulation_raster_experiment/open_loop_boxes/2023.04.25.17.31.09
#
# 2023-04-25 17:31:13,997 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:35}
#
# 	Folder where all results are stored: /tmp/tutorial_nuplan_framework/simulation_raster_experiment/open_loop_boxes/2023.04.25.17.31.09
#
# 2023-04-25 17:31:13,999 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:70}  Building experiment folders...DONE!
# 2023-04-25 17:31:13,999 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:70}  Building experiment folders...DONE!
# 2023-04-25 17:31:13,999 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2023-04-25 17:31:13,999 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2023-04-25 17:31:13,999 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:68}  Building AbstractCallback: 0...DONE!
# 2023-04-25 17:31:13,999 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:68}  Building AbstractCallback: 0...DONE!
# 2023-04-25 17:31:14,000 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:47}  Building simulations...
# 2023-04-25 17:31:14,000 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:47}  Building simulations...
# 2023-04-25 17:31:14,000 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:53}  Extracting scenarios...
# 2023-04-25 17:31:14,000 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:53}  Extracting scenarios...
# 2023-04-25 17:31:14,000 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/common/utils/distributed_scenario_filter.py:83}  Building Scenarios in mode DistributedMode.SINGLE_NODE
# 2023-04-25 17:31:14,000 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/common/utils/distributed_scenario_filter.py:83}  Building Scenarios in mode DistributedMode.SINGLE_NODE
# 2023-04-25 17:31:14,000 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2023-04-25 17:31:14,000 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2023-04-25 17:31:14,014 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2023-04-25 17:31:14,014 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2023-04-25 17:31:14,014 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2023-04-25 17:31:14,014 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2023-04-25 17:31:14,015 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# 2023-04-25 17:31:14,015 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# Ray objects: 100%|████████████████████████████████████████████████████████████████████| 32/32 [00:02<00:00, 15.29it/s]
# 2023-04-25 17:31:16,146 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:74}  Building metric engines...
# 2023-04-25 17:31:16,146 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:74}  Building metric engines...
# 2023-04-25 17:31:16,171 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:76}  Building metric engines...DONE
# 2023-04-25 17:31:16,171 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:76}  Building metric engines...DONE
# 2023-04-25 17:31:16,171 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:80}  Building simulations from 31 scenarios...
# 2023-04-25 17:31:16,171 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:80}  Building simulations from 31 scenarios...
# 2023-04-25 17:31:16,173 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:16,173 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:16,383 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:16,383 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:16,417 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:16,417 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:16,438 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:16,438 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:16,811 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:16,811 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:17,007 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:17,007 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:17,026 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:17,026 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:17,043 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:17,043 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:17,216 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:17,216 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:17,407 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:17,407 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:17,428 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:17,428 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:17,445 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:17,445 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:17,855 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:17,855 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:18,045 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:18,045 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:18,063 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:18,063 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:18,080 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:18,080 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:18,450 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:18,450 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:18,641 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:18,641 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:18,663 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:18,663 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:18,680 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:18,680 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:18,854 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:18,854 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:19,046 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:19,046 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:19,063 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:19,063 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:19,081 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:19,081 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:19,481 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:19,481 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:19,672 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:19,672 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:19,693 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:19,693 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:19,710 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:19,710 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:20,089 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:20,089 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:20,280 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:20,280 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:20,298 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:20,298 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:20,316 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:20,316 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:20,480 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:20,480 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:20,673 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:20,673 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:20,695 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:20,695 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:20,712 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:20,712 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:21,125 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:21,125 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:21,318 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:21,318 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:21,336 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:21,336 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:21,354 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:21,354 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:21,719 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:21,719 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:21,911 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:21,911 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:21,933 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:21,933 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:21,951 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:21,951 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:22,130 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:22,130 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:22,322 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:22,322 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:22,340 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:22,340 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:22,357 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:22,357 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:22,760 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:22,760 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:22,954 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:22,954 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:22,976 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:22,976 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:22,994 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:22,994 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:23,372 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:23,372 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:23,571 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:23,571 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:23,589 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:23,589 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:23,607 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:23,607 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:23,770 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:23,770 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:23,964 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:23,964 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:23,985 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:23,985 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:24,003 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:24,003 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:24,409 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:24,409 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:24,599 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:24,599 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:24,617 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:24,617 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:24,635 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:24,635 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:25,001 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:25,001 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:25,191 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:25,191 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:25,212 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:25,212 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:25,230 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:25,230 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:25,400 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:25,400 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:25,590 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:25,590 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:25,608 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:25,608 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:25,625 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:25,625 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:26,026 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:26,026 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:26,217 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:26,217 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:26,238 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:26,238 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:26,256 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:26,256 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:26,629 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:26,629 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:26,819 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:26,819 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:26,837 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:26,837 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:26,855 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:26,855 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:27,019 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:27,019 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:27,211 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:27,211 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:27,231 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:27,231 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:27,249 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:27,249 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:27,659 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:27,659 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:27,850 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:27,850 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:27,869 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:27,869 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:27,890 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:27,890 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:28,260 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:28,260 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:28,453 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:28,453 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:28,474 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:28,474 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:28,492 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:28,492 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:28,661 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:28,661 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:28,853 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:28,853 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:28,871 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:28,871 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:28,888 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:28,888 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:29,296 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:29,296 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2023-04-25 17:31:29,489 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:29,489 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:247}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2023-04-25 17:31:29,510 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:29,510 INFO {/home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/helpers.py:275}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2023-04-25 17:31:29,527 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:29,527 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2023-04-25 17:31:29,910 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# ...
# 2023-04-25 17:31:33,040 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/run_simulation.py:78}  Running simulation...
# 2023-04-25 17:31:33,041 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/utils.py:138}  Executing runners...
# 2023-04-25 17:31:33,041 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/script/utils.py:138}  Executing runners...
# 2023-04-25 17:31:33,041 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:82}  Starting 31 simulations using RayDistributed!
# 2023-04-25 17:31:33,041 INFO {/home/pat.karnchanachari/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:82}  Starting 31 simulations using RayDistributed!
# Ray objects:   0%|                                                                             | 0/31 [00:00<?, ?it/s](wrapped_fn pid=32670) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32670)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32668) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32668)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32662) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32662)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32657) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32657)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32652) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32652)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32675) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32675)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32650) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32650)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32654) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32654)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32665) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32665)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32671) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32671)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32674) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32674)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32661) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32661)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32672) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32672)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32655) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32655)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32660) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32660)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32649) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32649)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32666) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32666)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32663) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32663)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32648) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32648)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32656) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32656)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32647) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32647)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32651) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32651)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32658) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32658)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32673) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32673)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32676) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32676)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32678) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32678)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32659) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32659)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32664) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32664)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32677) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32677)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32669) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32669)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=32653) /home/pat.karnchanachari/miniconda3/envs/nuplan/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=32653)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %% [markdown]
# # Visualizing metrics and scenarios <a name="dashboard"></a>

# %% [markdown]
# ## nuBoard summary
#
# Having trained and simulated planners across various scenarios and driving behaviors, it's time to evaluate them:
# * quantitatively, through common and scenario dependent metrics
# * qualitatively, through visualization of scenario progression
#
# ### nuBoard tabs
# To achieve that, nuBoard has 3 core evaluation tabs:
# 1. Overview - Scalar metrics summary of common and scenario metrics across the following categories:
#     * Ego dynamics
#     * Traffic violations
#     * Expert imitation
#     * Planning & navigation
#     * Scenario performance
# 2. Histograms - Histograms over metric statistics for more a granular peek inside each metric focusing on:
#     * Metric statistics (e.g. min, max, p90)
# 3. Scenarios - Low-level scenario visualizations:
#     * Time-series progression of a specific metric across a scenario
#     * Top-down visualization of the scenario across time for comparing predicted vs. expert trajectories
#
# In addition, there is a main configuration tab for selecting different simulation files for comparing planners/experiments.
#
# <br />
#
# **NOTE**: nuBoard is under heavy developement, overall functionality and aesthetics do not represent the final product!

# %% [markdown]
# ## Prepare the nuBoard config

# %%
# Location of path with all nuBoard configs
CONFIG_PATH = '../nuplan/planning/script/config/nuboard'
CONFIG_NAME = 'default_nuboard'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    'scenario_builder=nuplan_mini',  # set the database (same as simulation) used to fetch data for visualization
    f'simulation_path={[simple_simulation_folder, ml_planner_simulation_folder]}',  # nuboard file path(s), if left empty the user can open the file inside nuBoard
])

# %% [markdown]
# ## Launch nuBoard (open in new tab - recommended)

# %%
from nuplan.planning.script.run_nuboard import main as main_nuboard

# Run nuBoard
main_nuboard(cfg)

# %% [markdown]
# ## Launch nuBoard (embedded within the notebook - alternative)

# %%
from bokeh.io import show, output_notebook
from nuplan.planning.script.run_nuboard import initialize_nuboard

# Make sure that the notebook working directory is "/notebooks" and that Jupyter was launched at the root of the repo
cfg.resource_prefix = '/notebooks/nuplan/planning/metrics/board/'  # pass CSS resources to the notebook

# Run the nuBoard
output_notebook()
nuboard = initialize_nuboard(cfg)
show(nuboard.main_page)

# %% [markdown]
# ## Launch nuBoard (command line - alternative)

# %% [markdown]
# nuBoard can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_nuboard.py
# ```
#
# Simulation files (.nuboard) can be selected under the configuration tab.
